# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  2025KORBRES1.pdf			      'ML Exam 1 Notes.gdoc'
#  Adobe_CL.gdoc				      'ML Track.gsheet'
#  Adobe_CL_R149343.gdoc			       Muse
#  Adobe_CL_R149564.gdoc			      'Notes - Dhruvi (Applied ML) OH.gdoc'
# 'AES Innovation Challenge'		      'Note-Taker Sample Sheet.docx'
#  Ai2_CL.gdoc				       NovoNordisk_CL.gdoc
#  AI2.gdoc				       Ontra_CL.gdoc
# 'AML brainstorm .gdoc'			       Oracle_CL.gdoc
#  AML_project				      'Phase 2 Wrap Up'
# 'AML-Project-Group 26 Proposal.gdoc'	      'profilepic (1).jpg'
# 'AML Review .gdoc'			       profilepic.jpg
# 'Anacker Lab'				      'Resume_Jan2025_1 (1).pdf'
#  AnackerLabRevLearningVid		      'Resume_Jan2025_1 (2).pdf'
# 'ASSIGNMENT 2: Innovation Concept Plan.gdoc'   Resume_Jan2025_1.pdf
#  Atlassian_CL.gdoc			       Salesforce_AI_CL.gdoc
#  Beli_CL.gdoc				       sarahkorbresume_25.pdf
#  braeswood_carbon.gdoc			       Scale
#  Brookings_CL_3575.gdoc			       scale_2.gdoc
# 'Brookings_CL_3608 .gdoc'		      'SK2024_1 (1).pdf'
# ...

# %%
# Set Git global username and email (if you haven't done so already)
# !git config --global user.name "sarahkorb"
# !git config --global user.email "sarahkorb9@gmail.com"

# Cache credentials temporarily
# !git config --global credential.helper cache

# %%
# !git clone https://sarahkorb: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@github.com/maria-garmonina/html-final-project.git
# Out:
# Cloning into 'html-final-project'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (167/167), done.
# remote: Total 170 (delta 24), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (170/170), 250.65 KiB | 2.82 MiB/s, done.
# Resolving deltas: 100% (24/24), done.

# %%
cd html-final-project/
# Out:
# /html-final-project/html-final-project

# %%
# !cp /content/drive/MyDrive/HPML_Bamba.ipynb /content/your-forked-repo/
# Out:
#  2025KORBRES1.pdf			      'ML Exam 1 Notes.gdoc'
#  Adobe_CL.gdoc				      'ML Track.gsheet'
#  Adobe_CL_R149343.gdoc			       Muse
#  Adobe_CL_R149564.gdoc			      'Notes - Dhruvi (Applied ML) OH.gdoc'
# 'AES Innovation Challenge'		      'Note-Taker Sample Sheet.docx'
#  Ai2_CL.gdoc				       NovoNordisk_CL.gdoc
#  AI2.gdoc				       Ontra_CL.gdoc
# 'AML brainstorm .gdoc'			       Oracle_CL.gdoc
#  AML_project				      'Phase 2 Wrap Up'
# 'AML-Project-Group 26 Proposal.gdoc'	      'profilepic (1).jpg'
# 'AML Review .gdoc'			       profilepic.jpg
# 'Anacker Lab'				      'Resume_Jan2025_1 (1).pdf'
#  AnackerLabRevLearningVid		      'Resume_Jan2025_1 (2).pdf'
# 'ASSIGNMENT 2: Innovation Concept Plan.gdoc'   Resume_Jan2025_1.pdf
#  Atlassian_CL.gdoc			       Salesforce_AI_CL.gdoc
#  Beli_CL.gdoc				       sarahkorbresume_25.pdf
#  braeswood_carbon.gdoc			       Scale
#  Brookings_CL_3575.gdoc			       scale_2.gdoc
# 'Brookings_CL_3608 .gdoc'		      'SK2024_1 (1).pdf'
# ...

# %%
# !git add HPML _Bamba.ipynb
# Out:
# fatal: pathspec 'HPML' did not match any files

# %%
# !git commit -m "Add Colab notebook"
# !git push origin master
